# %%
import tensorflow as tf
# inceptionv3 imports
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D

#callback imports
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import pandas as pd

# %%
batch_size = 32
epochs = 5
img_size = (224,224)
classes = 4

# %%
# Create directories
from pathlib import Path

original_dataset_path = Path('new_dataset/')

base_path = Path('new_dataset/')
base_path.mkdir(parents=True, exist_ok=True)

train_path = base_path / 'train'
train_path.mkdir(parents=True, exist_ok=True)

validation_path = base_path / 'val'
validation_path.mkdir(parents=True, exist_ok=True)

test_path = base_path / 'test'
#test_path.mkdir(parents=True, exist_ok=True)

# %%
# create the base pre-trained model
base_model = InceptionV3(weights='imagenet', include_top=False)

# add a global spatial average pooling layer
x = base_model.output
x = GlobalAveragePooling2D()(x)
# let's add a fully-connected layer
x = Dense(1024, activation='relu')(x)
# and a logistic layer -- let's say we have 200 classes
predictions = Dense(classes, activation='softmax')(x)

# this is the model we will train
model = Model(inputs=base_model.input, outputs=predictions)

# first: train only the top layers (which were randomly initialized)
# i.e. freeze all convolutional InceptionV3 layers
for layer in base_model.layers:
    layer.trainable = False

# compile the model (should be done *after* setting layers to non-trainable)
model.compile(optimizer='rmsprop', 
              loss='categorical_crossentropy', 
              metrics=[tf.keras.metrics.Accuracy(), tf.keras.metrics.CategoricalAccuracy()])

# %%
train_datagen = ImageDataGenerator(rescale=1./255)
validation_datagen = ImageDataGenerator(rescale=1./255)
train_generator = train_datagen.flow_from_directory(
    str(train_path),
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical')

validation_generator = validation_datagen.flow_from_directory(
    str(validation_path),
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical')
# Out:
# Found 8860 images belonging to 4 classes.
# Found 20 images belonging to 4 classes.

# %%
#callbacks for first learning stage
tensorboard_callback = TensorBoard(log_dir="./logs_new/stage1")
filepath = "saved-model-{epoch:02d}-stage1.hdf5"
checkpoint_callback = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=False, mode='max')

# %%
# TODO = validation_split=0.30 ?
history = model.fit(
    train_generator,
    steps_per_epoch=len(train_generator),
    epochs=5,
    validation_data=validation_generator, 
    validation_steps=len(validation_generator),
    callbacks=[tensorboard_callback, checkpoint_callback]
)
# Out:
# Epoch 1/5
# 277/277 [==============================] - ETA: 0s - loss: 0.2936 - accuracy: 0.0606 - categorical_accuracy: 0.9512
# Epoch 00001: saving model to saved-model-01-stage1.hdf5
# 277/277 [==============================] - 189s 681ms/step - loss: 0.2936 - accuracy: 0.0606 - categorical_accuracy: 0.9512 - val_loss: 0.5330 - val_accuracy: 0.0125 - val_categorical_accuracy: 0.8500
# Epoch 2/5
# 277/277 [==============================] - ETA: 0s - loss: 0.0604 - accuracy: 0.1793 - categorical_accuracy: 0.9895
# Epoch 00002: saving model to saved-model-02-stage1.hdf5
# 277/277 [==============================] - 178s 642ms/step - loss: 0.0604 - accuracy: 0.1793 - categorical_accuracy: 0.9895 - val_loss: 0.4802 - val_accuracy: 0.0875 - val_categorical_accuracy: 0.9500
# Epoch 3/5
# 277/277 [==============================] - ETA: 0s - loss: 0.0426 - accuracy: 0.2233 - categorical_accuracy: 0.9932
# Epoch 00003: saving model to saved-model-03-stage1.hdf5
# 277/277 [==============================] - 193s 697ms/step - loss: 0.0426 - accuracy: 0.2233 - categorical_accuracy: 0.9932 - val_loss: 0.8113 - val_accuracy: 0.1375 - val_categorical_accuracy: 0.8500
# Epoch 4/5
# 277/277 [==============================] - ETA: 0s - loss: 0.0227 - accuracy: 0.2437 - categorical_accuracy: 0.9966
# Epoch 00004: saving model to saved-model-04-stage1.hdf5
# 277/277 [==============================] - 193s 698ms/step - loss: 0.0227 - accuracy: 0.2437 - categorical_accuracy: 0.9966 - val_loss: 1.2883 - val_accuracy: 0.1750 - val_categorical_accuracy: 0.9000
# Epoch 5/5
# 277/277 [==============================] - ETA: 0s - loss: 0.0214 - accuracy: 0.3192 - categorical_accuracy: 0.9962
# Epoch 00005: saving model to saved-model-05-stage1.hdf5
# 277/277 [==============================] - 195s 705ms/step - loss: 0.0214 - accuracy: 0.3192 - categorical_accuracy: 0.9962 - val_loss: 0.6503 - val_accuracy: 0.1750 - val_categorical_accuracy: 0.9000

# %%
# at this point, the top layers are well trained and we can start fine-tuning
# convolutional layers from inception V3. We will freeze the bottom N layers
# and train the remaining top layers.

# let's visualize layer names and layer indices to see how many layers
# we should freeze:
layers = [(layer, layer.name, layer.trainable) for layer in base_model.layers]
df = pd.DataFrame(layers, columns=['Layer Type', 'Layer Name', 'Layer Trainable'])
with pd.option_context('display.max_rows', None, 'display.max_columns', None): 
    display(df)
#for i, layer in enumerate(base_model.layers):
#   print(i, layer.name)

# we chose to train the top 2 inception blocks, i.e. we will freeze
# the first 249 layers and unfreeze the rest:
for layer in model.layers[:249]:
   layer.trainable = False
for layer in model.layers[249:]:
   layer.trainable = True

# we need to recompile the model for these modifications to take effect
# we use SGD with a low learning rate
from tensorflow.keras.optimizers import SGD
model.compile(optimizer=SGD(lr=0.0001, momentum=0.9), loss='categorical_crossentropy', metrics=['accuracy', 'categorical_accuracy'])
# Out:
#                                             Layer Type  \
# 0    <tensorflow.python.keras.engine.input_layer.In...
# 1    <tensorflow.python.keras.layers.convolutional....
# 2    <tensorflow.python.keras.layers.normalization_...
# 3    <tensorflow.python.keras.layers.core.Activatio...
# 4    <tensorflow.python.keras.layers.convolutional....
# 5    <tensorflow.python.keras.layers.normalization_...
# 6    <tensorflow.python.keras.layers.core.Activatio...
# 7    <tensorflow.python.keras.layers.convolutional....
# 8    <tensorflow.python.keras.layers.normalization_...
# 9    <tensorflow.python.keras.layers.core.Activatio...
# 10   <tensorflow.python.keras.layers.pooling.MaxPoo...
# 11   <tensorflow.python.keras.layers.convolutional....
# 12   <tensorflow.python.keras.layers.normalization_...
# 13   <tensorflow.python.keras.layers.core.Activatio...
# 14   <tensorflow.python.keras.layers.convolutional....
# 15   <tensorflow.python.keras.layers.normalization_...
# 16   <tensorflow.python.keras.layers.core.Activatio...
# 17   <tensorflow.python.keras.layers.pooling.MaxPoo...
# 18   <tensorflow.python.keras.layers.convolutional....
# 19   <tensorflow.python.keras.layers.normalization_...
# 20   <tensorflow.python.keras.layers.core.Activatio...
# 21   <tensorflow.python.keras.layers.convolutional....
# 22   <tensorflow.python.keras.layers.convolutional....
# 23   <tensorflow.python.keras.layers.normalization_...
# 24   <tensorflow.python.keras.layers.normalization_...
# 25   <tensorflow.python.keras.layers.core.Activatio...
# 26   <tensorflow.python.keras.layers.core.Activatio...
# 27   <tensorflow.python.keras.layers.pooling.Averag...
# 28   <tensorflow.python.keras.layers.convolutional....
# 29   <tensorflow.python.keras.layers.convolutional....
# 30   <tensorflow.python.keras.layers.convolutional....
# 31   <tensorflow.python.keras.layers.convolutional....
# 32   <tensorflow.python.keras.layers.normalization_...
# 33   <tensorflow.python.keras.layers.normalization_...
# 34   <tensorflow.python.keras.layers.normalization_...
# 35   <tensorflow.python.keras.layers.normalization_...
# 36   <tensorflow.python.keras.layers.core.Activatio...
# 37   <tensorflow.python.keras.layers.core.Activatio...
# 38   <tensorflow.python.keras.layers.core.Activatio...
# 39   <tensorflow.python.keras.layers.core.Activatio...
# 40   <tensorflow.python.keras.layers.merge.Concaten...
# 41   <tensorflow.python.keras.layers.convolutional....
# 42   <tensorflow.python.keras.layers.normalization_...
# 43   <tensorflow.python.keras.layers.core.Activatio...
# 44   <tensorflow.python.keras.layers.convolutional....
# 45   <tensorflow.python.keras.layers.convolutional....
# 46   <tensorflow.python.keras.layers.normalization_...
# 47   <tensorflow.python.keras.layers.normalization_...
# 48   <tensorflow.python.keras.layers.core.Activatio...
# 49   <tensorflow.python.keras.layers.core.Activatio...
# 50   <tensorflow.python.keras.layers.pooling.Averag...
# 51   <tensorflow.python.keras.layers.convolutional....
# 52   <tensorflow.python.keras.layers.convolutional....
# 53   <tensorflow.python.keras.layers.convolutional....
# 54   <tensorflow.python.keras.layers.convolutional....
# 55   <tensorflow.python.keras.layers.normalization_...
# 56   <tensorflow.python.keras.layers.normalization_...
# 57   <tensorflow.python.keras.layers.normalization_...
# 58   <tensorflow.python.keras.layers.normalization_...
# 59   <tensorflow.python.keras.layers.core.Activatio...
# 60   <tensorflow.python.keras.layers.core.Activatio...
# 61   <tensorflow.python.keras.layers.core.Activatio...
# 62   <tensorflow.python.keras.layers.core.Activatio...
# 63   <tensorflow.python.keras.layers.merge.Concaten...
# 64   <tensorflow.python.keras.layers.convolutional....
# 65   <tensorflow.python.keras.layers.normalization_...
# 66   <tensorflow.python.keras.layers.core.Activatio...
# 67   <tensorflow.python.keras.layers.convolutional....
# 68   <tensorflow.python.keras.layers.convolutional....
# 69   <tensorflow.python.keras.layers.normalization_...
# 70   <tensorflow.python.keras.layers.normalization_...
# 71   <tensorflow.python.keras.layers.core.Activatio...
# 72   <tensorflow.python.keras.layers.core.Activatio...
# 73   <tensorflow.python.keras.layers.pooling.Averag...
# 74   <tensorflow.python.keras.layers.convolutional....
# 75   <tensorflow.python.keras.layers.convolutional....
# 76   <tensorflow.python.keras.layers.convolutional....
# 77   <tensorflow.python.keras.layers.convolutional....
# 78   <tensorflow.python.keras.layers.normalization_...
# 79   <tensorflow.python.keras.layers.normalization_...
# 80   <tensorflow.python.keras.layers.normalization_...
# 81   <tensorflow.python.keras.layers.normalization_...
# 82   <tensorflow.python.keras.layers.core.Activatio...
# 83   <tensorflow.python.keras.layers.core.Activatio...
# 84   <tensorflow.python.keras.layers.core.Activatio...
# 85   <tensorflow.python.keras.layers.core.Activatio...
# 86   <tensorflow.python.keras.layers.merge.Concaten...
# 87   <tensorflow.python.keras.layers.convolutional....
# 88   <tensorflow.python.keras.layers.normalization_...
# 89   <tensorflow.python.keras.layers.core.Activatio...
# 90   <tensorflow.python.keras.layers.convolutional....
# 91   <tensorflow.python.keras.layers.normalization_...
# 92   <tensorflow.python.keras.layers.core.Activatio...
# 93   <tensorflow.python.keras.layers.convolutional....
# 94   <tensorflow.python.keras.layers.convolutional....
# 95   <tensorflow.python.keras.layers.normalization_...
# 96   <tensorflow.python.keras.layers.normalization_...
# 97   <tensorflow.python.keras.layers.core.Activatio...
# 98   <tensorflow.python.keras.layers.core.Activatio...
# 99   <tensorflow.python.keras.layers.pooling.MaxPoo...
# 100  <tensorflow.python.keras.layers.merge.Concaten...
# 101  <tensorflow.python.keras.layers.convolutional....
# 102  <tensorflow.python.keras.layers.normalization_...
# 103  <tensorflow.python.keras.layers.core.Activatio...
# 104  <tensorflow.python.keras.layers.convolutional....
# 105  <tensorflow.python.keras.layers.normalization_...
# 106  <tensorflow.python.keras.layers.core.Activatio...
# 107  <tensorflow.python.keras.layers.convolutional....
# 108  <tensorflow.python.keras.layers.convolutional....
# 109  <tensorflow.python.keras.layers.normalization_...
# 110  <tensorflow.python.keras.layers.normalization_...
# 111  <tensorflow.python.keras.layers.core.Activatio...
# 112  <tensorflow.python.keras.layers.core.Activatio...
# 113  <tensorflow.python.keras.layers.convolutional....
# 114  <tensorflow.python.keras.layers.convolutional....
# 115  <tensorflow.python.keras.layers.normalization_...
# 116  <tensorflow.python.keras.layers.normalization_...
# 117  <tensorflow.python.keras.layers.core.Activatio...
# 118  <tensorflow.python.keras.layers.core.Activatio...
# 119  <tensorflow.python.keras.layers.pooling.Averag...
# 120  <tensorflow.python.keras.layers.convolutional....
# 121  <tensorflow.python.keras.layers.convolutional....
# 122  <tensorflow.python.keras.layers.convolutional....
# 123  <tensorflow.python.keras.layers.convolutional....
# 124  <tensorflow.python.keras.layers.normalization_...
# 125  <tensorflow.python.keras.layers.normalization_...
# 126  <tensorflow.python.keras.layers.normalization_...
# 127  <tensorflow.python.keras.layers.normalization_...
# 128  <tensorflow.python.keras.layers.core.Activatio...
# 129  <tensorflow.python.keras.layers.core.Activatio...
# 130  <tensorflow.python.keras.layers.core.Activatio...
# 131  <tensorflow.python.keras.layers.core.Activatio...
# 132  <tensorflow.python.keras.layers.merge.Concaten...
# 133  <tensorflow.python.keras.layers.convolutional....
# 134  <tensorflow.python.keras.layers.normalization_...
# 135  <tensorflow.python.keras.layers.core.Activatio...
# 136  <tensorflow.python.keras.layers.convolutional....
# 137  <tensorflow.python.keras.layers.normalization_...
# 138  <tensorflow.python.keras.layers.core.Activatio...
# 139  <tensorflow.python.keras.layers.convolutional....
# 140  <tensorflow.python.keras.layers.convolutional....
# 141  <tensorflow.python.keras.layers.normalization_...
# 142  <tensorflow.python.keras.layers.normalization_...
# 143  <tensorflow.python.keras.layers.core.Activatio...
# 144  <tensorflow.python.keras.layers.core.Activatio...
# 145  <tensorflow.python.keras.layers.convolutional....
# 146  <tensorflow.python.keras.layers.convolutional....
# 147  <tensorflow.python.keras.layers.normalization_...
# 148  <tensorflow.python.keras.layers.normalization_...
# 149  <tensorflow.python.keras.layers.core.Activatio...
# 150  <tensorflow.python.keras.layers.core.Activatio...
# 151  <tensorflow.python.keras.layers.pooling.Averag...
# 152  <tensorflow.python.keras.layers.convolutional....
# 153  <tensorflow.python.keras.layers.convolutional....
# 154  <tensorflow.python.keras.layers.convolutional....
# 155  <tensorflow.python.keras.layers.convolutional....
# 156  <tensorflow.python.keras.layers.normalization_...
# 157  <tensorflow.python.keras.layers.normalization_...
# 158  <tensorflow.python.keras.layers.normalization_...
# 159  <tensorflow.python.keras.layers.normalization_...
# 160  <tensorflow.python.keras.layers.core.Activatio...
# 161  <tensorflow.python.keras.layers.core.Activatio...
# 162  <tensorflow.python.keras.layers.core.Activatio...
# 163  <tensorflow.python.keras.layers.core.Activatio...
# 164  <tensorflow.python.keras.layers.merge.Concaten...
# 165  <tensorflow.python.keras.layers.convolutional....
# 166  <tensorflow.python.keras.layers.normalization_...
# 167  <tensorflow.python.keras.layers.core.Activatio...
# 168  <tensorflow.python.keras.layers.convolutional....
# 169  <tensorflow.python.keras.layers.normalization_...
# 170  <tensorflow.python.keras.layers.core.Activatio...
# 171  <tensorflow.python.keras.layers.convolutional....
# 172  <tensorflow.python.keras.layers.convolutional....
# 173  <tensorflow.python.keras.layers.normalization_...
# 174  <tensorflow.python.keras.layers.normalization_...
# 175  <tensorflow.python.keras.layers.core.Activatio...
# 176  <tensorflow.python.keras.layers.core.Activatio...
# 177  <tensorflow.python.keras.layers.convolutional....
# 178  <tensorflow.python.keras.layers.convolutional....
# 179  <tensorflow.python.keras.layers.normalization_...
# 180  <tensorflow.python.keras.layers.normalization_...
# 181  <tensorflow.python.keras.layers.core.Activatio...
# 182  <tensorflow.python.keras.layers.core.Activatio...
# 183  <tensorflow.python.keras.layers.pooling.Averag...
# 184  <tensorflow.python.keras.layers.convolutional....
# 185  <tensorflow.python.keras.layers.convolutional....
# 186  <tensorflow.python.keras.layers.convolutional....
# 187  <tensorflow.python.keras.layers.convolutional....
# 188  <tensorflow.python.keras.layers.normalization_...
# 189  <tensorflow.python.keras.layers.normalization_...
# 190  <tensorflow.python.keras.layers.normalization_...
# 191  <tensorflow.python.keras.layers.normalization_...
# 192  <tensorflow.python.keras.layers.core.Activatio...
# 193  <tensorflow.python.keras.layers.core.Activatio...
# 194  <tensorflow.python.keras.layers.core.Activatio...
# 195  <tensorflow.python.keras.layers.core.Activatio...
# 196  <tensorflow.python.keras.layers.merge.Concaten...
# 197  <tensorflow.python.keras.layers.convolutional....
# 198  <tensorflow.python.keras.layers.normalization_...
# 199  <tensorflow.python.keras.layers.core.Activatio...
# 200  <tensorflow.python.keras.layers.convolutional....
# 201  <tensorflow.python.keras.layers.normalization_...
# 202  <tensorflow.python.keras.layers.core.Activatio...
# 203  <tensorflow.python.keras.layers.convolutional....
# 204  <tensorflow.python.keras.layers.convolutional....
# 205  <tensorflow.python.keras.layers.normalization_...
# 206  <tensorflow.python.keras.layers.normalization_...
# 207  <tensorflow.python.keras.layers.core.Activatio...
# 208  <tensorflow.python.keras.layers.core.Activatio...
# 209  <tensorflow.python.keras.layers.convolutional....
# 210  <tensorflow.python.keras.layers.convolutional....
# 211  <tensorflow.python.keras.layers.normalization_...
# 212  <tensorflow.python.keras.layers.normalization_...
# 213  <tensorflow.python.keras.layers.core.Activatio...
# 214  <tensorflow.python.keras.layers.core.Activatio...
# 215  <tensorflow.python.keras.layers.pooling.Averag...
# 216  <tensorflow.python.keras.layers.convolutional....
# 217  <tensorflow.python.keras.layers.convolutional....
# 218  <tensorflow.python.keras.layers.convolutional....
# 219  <tensorflow.python.keras.layers.convolutional....
# 220  <tensorflow.python.keras.layers.normalization_...
# 221  <tensorflow.python.keras.layers.normalization_...
# 222  <tensorflow.python.keras.layers.normalization_...
# 223  <tensorflow.python.keras.layers.normalization_...
# 224  <tensorflow.python.keras.layers.core.Activatio...
# 225  <tensorflow.python.keras.layers.core.Activatio...
# 226  <tensorflow.python.keras.layers.core.Activatio...
# 227  <tensorflow.python.keras.layers.core.Activatio...
# 228  <tensorflow.python.keras.layers.merge.Concaten...
# 229  <tensorflow.python.keras.layers.convolutional....
# 230  <tensorflow.python.keras.layers.normalization_...
# 231  <tensorflow.python.keras.layers.core.Activatio...
# 232  <tensorflow.python.keras.layers.convolutional....
# 233  <tensorflow.python.keras.layers.normalization_...
# 234  <tensorflow.python.keras.layers.core.Activatio...
# 235  <tensorflow.python.keras.layers.convolutional....
# 236  <tensorflow.python.keras.layers.convolutional....
# 237  <tensorflow.python.keras.layers.normalization_...
# 238  <tensorflow.python.keras.layers.normalization_...
# 239  <tensorflow.python.keras.layers.core.Activatio...
# 240  <tensorflow.python.keras.layers.core.Activatio...
# 241  <tensorflow.python.keras.layers.convolutional....
# 242  <tensorflow.python.keras.layers.convolutional....
# 243  <tensorflow.python.keras.layers.normalization_...
# 244  <tensorflow.python.keras.layers.normalization_...
# 245  <tensorflow.python.keras.layers.core.Activatio...
# 246  <tensorflow.python.keras.layers.core.Activatio...
# 247  <tensorflow.python.keras.layers.pooling.MaxPoo...
# 248  <tensorflow.python.keras.layers.merge.Concaten...
# 249  <tensorflow.python.keras.layers.convolutional....
# 250  <tensorflow.python.keras.layers.normalization_...
# 251  <tensorflow.python.keras.layers.core.Activatio...
# 252  <tensorflow.python.keras.layers.convolutional....
# 253  <tensorflow.python.keras.layers.convolutional....
# 254  <tensorflow.python.keras.layers.normalization_...
# 255  <tensorflow.python.keras.layers.normalization_...
# 256  <tensorflow.python.keras.layers.core.Activatio...
# 257  <tensorflow.python.keras.layers.core.Activatio...
# 258  <tensorflow.python.keras.layers.convolutional....
# 259  <tensorflow.python.keras.layers.convolutional....
# 260  <tensorflow.python.keras.layers.convolutional....
# 261  <tensorflow.python.keras.layers.convolutional....
# 262  <tensorflow.python.keras.layers.pooling.Averag...
# 263  <tensorflow.python.keras.layers.convolutional....
# 264  <tensorflow.python.keras.layers.normalization_...
# 265  <tensorflow.python.keras.layers.normalization_...
# 266  <tensorflow.python.keras.layers.normalization_...
# 267  <tensorflow.python.keras.layers.normalization_...
# 268  <tensorflow.python.keras.layers.convolutional....
# 269  <tensorflow.python.keras.layers.normalization_...
# 270  <tensorflow.python.keras.layers.core.Activatio...
# 271  <tensorflow.python.keras.layers.core.Activatio...
# 272  <tensorflow.python.keras.layers.core.Activatio...
# 273  <tensorflow.python.keras.layers.core.Activatio...
# 274  <tensorflow.python.keras.layers.normalization_...
# 275  <tensorflow.python.keras.layers.core.Activatio...
# 276  <tensorflow.python.keras.layers.merge.Concaten...
# 277  <tensorflow.python.keras.layers.merge.Concaten...
# 278  <tensorflow.python.keras.layers.core.Activatio...
# 279  <tensorflow.python.keras.layers.merge.Concaten...
# 280  <tensorflow.python.keras.layers.convolutional....
# 281  <tensorflow.python.keras.layers.normalization_...
# 282  <tensorflow.python.keras.layers.core.Activatio...
# 283  <tensorflow.python.keras.layers.convolutional....
# 284  <tensorflow.python.keras.layers.convolutional....
# 285  <tensorflow.python.keras.layers.normalization_...
# 286  <tensorflow.python.keras.layers.normalization_...
# 287  <tensorflow.python.keras.layers.core.Activatio...
# 288  <tensorflow.python.keras.layers.core.Activatio...
# 289  <tensorflow.python.keras.layers.convolutional....
# 290  <tensorflow.python.keras.layers.convolutional....
# 291  <tensorflow.python.keras.layers.convolutional....
# 292  <tensorflow.python.keras.layers.convolutional....
# 293  <tensorflow.python.keras.layers.pooling.Averag...
# 294  <tensorflow.python.keras.layers.convolutional....
# 295  <tensorflow.python.keras.layers.normalization_...
# 296  <tensorflow.python.keras.layers.normalization_...
# 297  <tensorflow.python.keras.layers.normalization_...
# 298  <tensorflow.python.keras.layers.normalization_...
# 299  <tensorflow.python.keras.layers.convolutional....
# 300  <tensorflow.python.keras.layers.normalization_...
# 301  <tensorflow.python.keras.layers.core.Activatio...
# 302  <tensorflow.python.keras.layers.core.Activatio...
# 303  <tensorflow.python.keras.layers.core.Activatio...
# 304  <tensorflow.python.keras.layers.core.Activatio...
# 305  <tensorflow.python.keras.layers.normalization_...
# 306  <tensorflow.python.keras.layers.core.Activatio...
# 307  <tensorflow.python.keras.layers.merge.Concaten...
# 308  <tensorflow.python.keras.layers.merge.Concaten...
# 309  <tensorflow.python.keras.layers.core.Activatio...
# 310  <tensorflow.python.keras.layers.merge.Concaten...
#
#                  Layer Name  Layer Trainable
# 0                   input_1            False
# 1                    conv2d            False
# 2       batch_normalization            False
# 3                activation            False
# 4                  conv2d_1            False
# 5     batch_normalization_1            False
# 6              activation_1            False
# 7                  conv2d_2            False
# 8     batch_normalization_2            False
# 9              activation_2            False
# 10            max_pooling2d            False
# 11                 conv2d_3            False
# 12    batch_normalization_3            False
# 13             activation_3            False
# 14                 conv2d_4            False
# 15    batch_normalization_4            False
# 16             activation_4            False
# 17          max_pooling2d_1            False
# 18                 conv2d_8            False
# 19    batch_normalization_8            False
# 20             activation_8            False
# 21                 conv2d_6            False
# 22                 conv2d_9            False
# 23    batch_normalization_6            False
# 24    batch_normalization_9            False
# 25             activation_6            False
# 26             activation_9            False
# 27        average_pooling2d            False
# 28                 conv2d_5            False
# 29                 conv2d_7            False
# 30                conv2d_10            False
# 31                conv2d_11            False
# 32    batch_normalization_5            False
# 33    batch_normalization_7            False
# 34   batch_normalization_10            False
# 35   batch_normalization_11            False
# 36             activation_5            False
# 37             activation_7            False
# 38            activation_10            False
# 39            activation_11            False
# 40                   mixed0            False
# 41                conv2d_15            False
# 42   batch_normalization_15            False
# 43            activation_15            False
# 44                conv2d_13            False
# 45                conv2d_16            False
# 46   batch_normalization_13            False
# 47   batch_normalization_16            False
# 48            activation_13            False
# 49            activation_16            False
# 50      average_pooling2d_1            False
# 51                conv2d_12            False
# 52                conv2d_14            False
# 53                conv2d_17            False
# 54                conv2d_18            False
# 55   batch_normalization_12            False
# 56   batch_normalization_14            False
# 57   batch_normalization_17            False
# 58   batch_normalization_18            False
# 59            activation_12            False
# 60            activation_14            False
# 61            activation_17            False
# 62            activation_18            False
# 63                   mixed1            False
# 64                conv2d_22            False
# 65   batch_normalization_22            False
# 66            activation_22            False
# 67                conv2d_20            False
# 68                conv2d_23            False
# 69   batch_normalization_20            False
# 70   batch_normalization_23            False
# 71            activation_20            False
# 72            activation_23            False
# 73      average_pooling2d_2            False
# 74                conv2d_19            False
# 75                conv2d_21            False
# 76                conv2d_24            False
# 77                conv2d_25            False
# 78   batch_normalization_19            False
# 79   batch_normalization_21            False
# 80   batch_normalization_24            False
# 81   batch_normalization_25            False
# 82            activation_19            False
# 83            activation_21            False
# 84            activation_24            False
# 85            activation_25            False
# 86                   mixed2            False
# 87                conv2d_27            False
# 88   batch_normalization_27            False
# 89            activation_27            False
# 90                conv2d_28            False
# 91   batch_normalization_28            False
# 92            activation_28            False
# 93                conv2d_26            False
# 94                conv2d_29            False
# 95   batch_normalization_26            False
# 96   batch_normalization_29            False
# 97            activation_26            False
# 98            activation_29            False
# 99          max_pooling2d_2            False
# 100                  mixed3            False
# 101               conv2d_34            False
# 102  batch_normalization_34            False
# 103           activation_34            False
# 104               conv2d_35            False
# 105  batch_normalization_35            False
# 106           activation_35            False
# 107               conv2d_31            False
# 108               conv2d_36            False
# 109  batch_normalization_31            False
# 110  batch_normalization_36            False
# 111           activation_31            False
# 112           activation_36            False
# 113               conv2d_32            False
# 114               conv2d_37            False
# 115  batch_normalization_32            False
# 116  batch_normalization_37            False
# 117           activation_32            False
# 118           activation_37            False
# 119     average_pooling2d_3            False
# 120               conv2d_30            False
# 121               conv2d_33            False
# 122               conv2d_38            False
# 123               conv2d_39            False
# 124  batch_normalization_30            False
# 125  batch_normalization_33            False
# 126  batch_normalization_38            False
# 127  batch_normalization_39            False
# 128           activation_30            False
# 129           activation_33            False
# 130           activation_38            False
# 131           activation_39            False
# 132                  mixed4            False
# 133               conv2d_44            False
# 134  batch_normalization_44            False
# 135           activation_44            False
# 136               conv2d_45            False
# 137  batch_normalization_45            False
# 138           activation_45            False
# 139               conv2d_41            False
# 140               conv2d_46            False
# 141  batch_normalization_41            False
# 142  batch_normalization_46            False
# 143           activation_41            False
# 144           activation_46            False
# 145               conv2d_42            False
# 146               conv2d_47            False
# 147  batch_normalization_42            False
# 148  batch_normalization_47            False
# 149           activation_42            False
# 150           activation_47            False
# 151     average_pooling2d_4            False
# 152               conv2d_40            False
# 153               conv2d_43            False
# 154               conv2d_48            False
# 155               conv2d_49            False
# 156  batch_normalization_40            False
# 157  batch_normalization_43            False
# 158  batch_normalization_48            False
# 159  batch_normalization_49            False
# 160           activation_40            False
# 161           activation_43            False
# 162           activation_48            False
# 163           activation_49            False
# 164                  mixed5            False
# 165               conv2d_54            False
# 166  batch_normalization_54            False
# 167           activation_54            False
# 168               conv2d_55            False
# 169  batch_normalization_55            False
# 170           activation_55            False
# 171               conv2d_51            False
# 172               conv2d_56            False
# 173  batch_normalization_51            False
# 174  batch_normalization_56            False
# 175           activation_51            False
# 176           activation_56            False
# 177               conv2d_52            False
# 178               conv2d_57            False
# 179  batch_normalization_52            False
# 180  batch_normalization_57            False
# 181           activation_52            False
# 182           activation_57            False
# 183     average_pooling2d_5            False
# 184               conv2d_50            False
# 185               conv2d_53            False
# 186               conv2d_58            False
# 187               conv2d_59            False
# 188  batch_normalization_50            False
# 189  batch_normalization_53            False
# 190  batch_normalization_58            False
# 191  batch_normalization_59            False
# 192           activation_50            False
# 193           activation_53            False
# 194           activation_58            False
# 195           activation_59            False
# 196                  mixed6            False
# 197               conv2d_64            False
# 198  batch_normalization_64            False
# 199           activation_64            False
# 200               conv2d_65            False
# 201  batch_normalization_65            False
# 202           activation_65            False
# 203               conv2d_61            False
# 204               conv2d_66            False
# 205  batch_normalization_61            False
# 206  batch_normalization_66            False
# 207           activation_61            False
# 208           activation_66            False
# 209               conv2d_62            False
# 210               conv2d_67            False
# 211  batch_normalization_62            False
# 212  batch_normalization_67            False
# 213           activation_62            False
# 214           activation_67            False
# 215     average_pooling2d_6            False
# 216               conv2d_60            False
# 217               conv2d_63            False
# 218               conv2d_68            False
# 219               conv2d_69            False
# 220  batch_normalization_60            False
# 221  batch_normalization_63            False
# 222  batch_normalization_68            False
# 223  batch_normalization_69            False
# 224           activation_60            False
# 225           activation_63            False
# 226           activation_68            False
# 227           activation_69            False
# 228                  mixed7            False
# 229               conv2d_72            False
# 230  batch_normalization_72            False
# 231           activation_72            False
# 232               conv2d_73            False
# 233  batch_normalization_73            False
# 234           activation_73            False
# 235               conv2d_70            False
# 236               conv2d_74            False
# 237  batch_normalization_70            False
# 238  batch_normalization_74            False
# 239           activation_70            False
# 240           activation_74            False
# 241               conv2d_71            False
# 242               conv2d_75            False
# 243  batch_normalization_71            False
# 244  batch_normalization_75            False
# 245           activation_71            False
# 246           activation_75            False
# 247         max_pooling2d_3            False
# 248                  mixed8            False
# 249               conv2d_80            False
# 250  batch_normalization_80            False
# 251           activation_80            False
# 252               conv2d_77            False
# 253               conv2d_81            False
# 254  batch_normalization_77            False
# 255  batch_normalization_81            False
# 256           activation_77            False
# 257           activation_81            False
# 258               conv2d_78            False
# 259               conv2d_79            False
# 260               conv2d_82            False
# 261               conv2d_83            False
# 262     average_pooling2d_7            False
# 263               conv2d_76            False
# 264  batch_normalization_78            False
# 265  batch_normalization_79            False
# 266  batch_normalization_82            False
# 267  batch_normalization_83            False
# 268               conv2d_84            False
# 269  batch_normalization_76            False
# 270           activation_78            False
# 271           activation_79            False
# 272           activation_82            False
# 273           activation_83            False
# 274  batch_normalization_84            False
# 275           activation_76            False
# 276                mixed9_0            False
# 277             concatenate            False
# 278           activation_84            False
# 279                  mixed9            False
# 280               conv2d_89            False
# 281  batch_normalization_89            False
# 282           activation_89            False
# 283               conv2d_86            False
# 284               conv2d_90            False
# 285  batch_normalization_86            False
# 286  batch_normalization_90            False
# 287           activation_86            False
# 288           activation_90            False
# 289               conv2d_87            False
# 290               conv2d_88            False
# 291               conv2d_91            False
# 292               conv2d_92            False
# 293     average_pooling2d_8            False
# 294               conv2d_85            False
# 295  batch_normalization_87            False
# 296  batch_normalization_88            False
# 297  batch_normalization_91            False
# 298  batch_normalization_92            False
# 299               conv2d_93            False
# 300  batch_normalization_85            False
# 301           activation_87            False
# 302           activation_88            False
# 303           activation_91            False
# 304           activation_92            False
# 305  batch_normalization_93            False
# 306           activation_85            False
# 307                mixed9_1            False
# 308           concatenate_1            False
# 309           activation_93            False
# 310                 mixed10            False

# %%
#callbacks for second learning stage
tensorboard_callback2 = TensorBoard(log_dir="./logs_new/stage2")
filepath2 = "saved-model-{epoch:02d}-stage2.hdf5"
checkpoint_callback2 = ModelCheckpoint(filepath2, monitor='val_accuracy', verbose=1, save_best_only=False, mode='max')

# %%
# TODO = validation_split=0.30 ?
history = model.fit(
    train_generator,
    steps_per_epoch=len(train_generator),
    epochs=epochs,
    validation_data=validation_generator, 
    validation_steps=len(validation_generator),
    callbacks=[tensorboard_callback2, checkpoint_callback2]
)
# Out:
# Epoch 1/5
# 277/277 [==============================] - ETA: 0s - loss: 0.0733 - accuracy: 0.9852 - categorical_accuracy: 0.9852
# Epoch 00001: saving model to saved-model-01-stage2.hdf5
# 277/277 [==============================] - 256s 923ms/step - loss: 0.0733 - accuracy: 0.9852 - categorical_accuracy: 0.9852 - val_loss: 0.5118 - val_accuracy: 0.8500 - val_categorical_accuracy: 0.8500
# Epoch 2/5
# 277/277 [==============================] - ETA: 0s - loss: 0.0121 - accuracy: 0.9962 - categorical_accuracy: 0.9962
# Epoch 00002: saving model to saved-model-02-stage2.hdf5
# 277/277 [==============================] - 259s 936ms/step - loss: 0.0121 - accuracy: 0.9962 - categorical_accuracy: 0.9962 - val_loss: 0.8416 - val_accuracy: 0.8500 - val_categorical_accuracy: 0.8500
# Epoch 3/5
# 277/277 [==============================] - ETA: 0s - loss: 0.0042 - accuracy: 0.9986 - categorical_accuracy: 0.9986
# Epoch 00003: saving model to saved-model-03-stage2.hdf5
# 277/277 [==============================] - 273s 986ms/step - loss: 0.0042 - accuracy: 0.9986 - categorical_accuracy: 0.9986 - val_loss: 0.7545 - val_accuracy: 0.8500 - val_categorical_accuracy: 0.8500
# Epoch 4/5
# 277/277 [==============================] - ETA: 0s - loss: 0.0041 - accuracy: 0.9985 - categorical_accuracy: 0.9985
# Epoch 00004: saving model to saved-model-04-stage2.hdf5
# 277/277 [==============================] - 256s 923ms/step - loss: 0.0041 - accuracy: 0.9985 - categorical_accuracy: 0.9985 - val_loss: 0.8635 - val_accuracy: 0.8500 - val_categorical_accuracy: 0.8500
# Epoch 5/5
# 277/277 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9997 - categorical_accuracy: 0.9997
# Epoch 00005: saving model to saved-model-05-stage2.hdf5
# 277/277 [==============================] - 251s 905ms/step - loss: 0.0012 - accuracy: 0.9997 - categorical_accuracy: 0.9997 - val_loss: 0.8419 - val_accuracy: 0.8500 - val_categorical_accuracy: 0.8500

# %%
test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
    str(test_path),
    target_size=img_size,
    batch_size=1,
    class_mode='categorical')
model.evaluate(test_generator, steps=20)
#print('test acc:', test_acc)
# Out:
# Found 20 images belonging to 4 classes.
# 20/20 [==============================] - 1s 55ms/step - loss: 0.8419 - accuracy: 0.8500 - categorical_accuracy: 0.8500
# [0.8419052958488464, 0.8500000238418579, 0.8500000238418579]

# %%
model.save('model_best_new_2.tf')
# Out:
# WARNING:tensorflow:From /home/konrad/.local/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: model_best_new_2.tf/assets
